# %% [markdown]
# # Machine Learning Evaluation & Operational Analytics
# **Domain:** Apparel, Textiles, and Fashion Retail

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

with open('../data/evaluation_metrics.json') as f:
    data = json.load(f)
print('Project:', data['project_metadata']['title'])
